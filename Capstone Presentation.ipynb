# %% [markdown]
# ![image.png](attachment:c3194d7f-2717-4331-ae8a-767955d62c72.png)
#
# ![image.png](attachment:138c8440-2558-4885-8d56-bffc16775996.png)
#
# ![image.png](attachment:fd5c7661-7d04-40d4-8550-4479885507a6.png)
#
# ![image.png](attachment:18f7e1e8-d02f-44c0-8b6d-fa8c179e72a5.png)
#
# ![image.png](attachment:9bca748a-3496-4a5b-9aad-fa49162c16f4.png)
#
# ![image.png](attachment:ad6242f2-c98f-49e2-b505-def21918d576.png)
#
# ![image.png](attachment:e6a71049-2919-4fb6-b41f-601cd2c80ff0.png)
#
# ![image.png](attachment:789b7a45-0444-49fd-ab92-91d6abe82591.png)
#
# ![image.png](attachment:b5ba0225-1747-461f-9c7d-6e0f6c0153bf.png)
#
# ![image.png](attachment:d9014681-a973-4e77-b9a2-2f7f9e2d32d2.png)
#
# ![image.png](attachment:3dbd41fc-f302-4308-858a-0b803d8691e7.png)
#
# ![image.png](attachment:88bfed1e-31af-49bb-9484-c1259cbe592a.png)
#
# ![image.png](attachment:cdfc3a50-00e6-4c70-81fa-c7e573d5f976.png)
